# %%
#Import packages
import os
import pandas as pd
import pytrends
import numpy as np
from datetime import datetime
from datetime import timedelta

from pytrends.request import TrendReq
import time
import logging

# %%
team_Abbr_csv = pd.read_csv('team_abbr_full.csv')

# %%
club_qb_df = pd.read_csv('clubs_mid.csv')

# %%
import os
import requests
os.environ['HTTPS_PROXY']="https://:Welcome123!@gurgaonproxy.corp.exlservice.com:8000"
os.environ['HTTP_PROXY']="http://sahil140352:Welcome123!@gurgaonproxy.corp.exlservice.com:8000"

# %%
club_df_list = []
club_final_out_list = []
error_list = []
j=0
k=0
i=0
tried = 0

for k in ['2/28/2019']:
    report_dt = k
    datestart = datetime.strptime(report_dt,'%m/%d/%Y').date() + timedelta(days=-365)
    dateend   = datetime.strptime(report_dt,'%m/%d/%Y').date() + timedelta(days=0)
    daterange = datestart.strftime('%Y')+'-'+datestart.strftime('%m')+'-'+datestart.strftime('%d') + ' ' + dateend.strftime('%Y')+'-'+dateend.strftime('%m')+'-'+dateend.strftime('%d')
    
    for index, row in club_qb_df.iterrows():
        region = 'US'###########for world?
        benchmark_team = 'Arizona Cardinals'
        benchmark_mid = '/m/0ws7'
           
        if row.loc['name'] != benchmark_team:
            #time.sleep(6)
            club_mid = row.loc['player_id']
            team = row.loc['name']
            print(report_dt,team)
            kw_list =[club_mid,benchmark_mid]

            tried = 0
            while tried < 5:
                try: 
                    pytrends = TrendReq(hl='en-US',tz=360,requests_args={'verify':False})
                    pytrends.build_payload(kw_list,cat=0,timeframe = daterange,geo=region,gprop='')
                    trend_df = pd.DataFrame(pytrends.interest_over_time())
                    trend_df.loc[:,'team_name'] = team
                    trend_df.columns = ['club','benchmark','isPartial','team_name']
                    trend_df = trend_df.reset_index()
                    trend_df['Season'] = k[len(k) - 4:]
                    club_df_list.append(trend_df)
                    print(trend_df)
                    tried = 5
                except:
                    print(tried)
                    time.sleep(60)
                    if tried == 4:
                        logging.warning("attempt failed for"+row.loc['name']+"at"+str(time.ctime()))
                    tried +=1
                    
    final_club_df = pd.concat(club_df_list,ignore_index=True)
# Out:
# 2/28/2019 Atlanta Falcons
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gurgaonproxy.corp.exlservice.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gurgaonproxy.corp.exlservice.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
club_df_list = []
club_final_out_list = []
error_list = []
j=0
k=0
i=0
tried = 0

for k in ['2/28/2019']:      
    report_dt = k
    datestart = datetime.strptime(report_dt,'%m/%d/%Y').date() + timedelta(days=-365)
    dateend   = datetime.strptime(report_dt,'%m/%d/%Y').date() + timedelta(days=0)
    daterange = datestart.strftime('%Y')+'-'+datestart.strftime('%m')+'-'+datestart.strftime('%d') + ' ' + dateend.strftime('%Y')+'-'+dateend.strftime('%m')+'-'+dateend.strftime('%d')
    
    for index, row in club_qb_df.iterrows():
        region = 'US'
        benchmark_team = 'Arizona Cardinals'
        benchmark_mid = '/m/0ws7'
      
        if row.loc['name'] == benchmark_team:
            #time.sleep(6)
            club_mid = row.loc['player_id']
            team = row.loc['name']
            print(report_dt,team)
            kw_list =[club_mid]

            tried = 0
            while tried < 5:
                try: 
                    pytrends = TrendReq(hl='en-US',tz=360,requests_args={'verify':False})
                    pytrends.build_payload(kw_list,cat=0,timeframe = daterange,geo=region,gprop='')
                    trend_df = pd.DataFrame(pytrends.interest_over_time())
                    trend_df.loc[:,'team_name'] = team
                    trend_df.columns = ['club','isPartial','team_name']
                    trend_df = trend_df.reset_index()
                    trend_df['Season'] = k[len(k) - 4:]
                    club_df_list.append(trend_df)
                    print(trend_df)
                    tried = 5
                except:
                    print(tried)
                    time.sleep(60)
                    if tried == 4:
                        logging.warning("attempt failed for"+row.loc['name']+"at"+str(time.ctime()))
                    tried +=1
                    
    final_club_benchmark = pd.concat(club_df_list,ignore_index=True)
    final_club_benchmark['benchmark'] = 1
# Out:
# 2/28/2019 Arizona Cardinals
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gurgaonproxy.corp.exlservice.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gurgaonproxy.corp.exlservice.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
#final_club_df.to_csv('GTI_Teams_raw.csv',index=False)

# %%
# Add month column and Week Type

final_club_df['month'] = final_club_df['date'].dt.month

conditions = [
    (final_club_df['month'] == 1),
    (final_club_df['month'] == 2),
    (final_club_df['month'] == 3),
    (final_club_df['month'] == 4),
    (final_club_df['month'] == 5),
    (final_club_df['month'] == 6),
    (final_club_df['month'] == 7),
    (final_club_df['month'] == 8),
    (final_club_df['month'] == 9),
    (final_club_df['month'] == 10),
    (final_club_df['month'] == 11),
    (final_club_df['month'] == 12)
]

# create a list of the values we want to assign for each condition
values = ['Post','Post', 'Off','Off','Off','Off','Off','Off', 'Reg','Reg','Reg','Reg']

# create a new column and use np.select to assign values to it using our lists as arguments
final_club_df['Week'] = np.select(conditions, values)

# Add month column and Week Type

final_club_benchmark['month'] = final_club_benchmark['date'].dt.month

conditions = [
    (final_club_benchmark['month'] == 1),
    (final_club_benchmark['month'] == 2),
    (final_club_benchmark['month'] == 3),
    (final_club_benchmark['month'] == 4),
    (final_club_benchmark['month'] == 5),
    (final_club_benchmark['month'] == 6),
    (final_club_benchmark['month'] == 7),
    (final_club_benchmark['month'] == 8),
    (final_club_benchmark['month'] == 9),
    (final_club_benchmark['month'] == 10),
    (final_club_benchmark['month'] == 11),
    (final_club_benchmark['month'] == 12)

]

# create a list of the values we want to assign for each condition
values = ['Post','Post', 'Off','Off','Off','Off','Off','Off', 'Reg','Reg','Reg','Reg']

# create a new column and use np.select to assign values to it using our lists as arguments
final_club_benchmark['Week'] = np.select(conditions, values)

# %%
# Manual Calculation for Few Clubs

#Year_list = ['2021']
#month_list = [12]

#Club_list = ['Kansas City Chiefs','Green Bay Packers','Dallas Cowboys']
#df = final_club_df[final_club_df['team_name'].isin(Club_list) & final_club_df['month'].isin(month_list) & final_club_df['Season'].isin(Year_list)  ]

#df = df.groupby(
#    ['date']
#).agg(
#    {
#        'club': ['mean'],
#    }
#)

#df.columns = ['AvgClub']
#df = df.reset_index()

#df

# %%
#final_club_df.loc[(final_club_df['team_name'] == 'Pittsburgh Steelers') & (final_club_df['date'] == '2020-12-06'),'club'] = 37
#final_club_df.loc[(final_club_df['team_name'] == 'Pittsburgh Steelers') & (final_club_df['date'] == '2020-12-13'),'club'] = 31
#final_club_df.loc[(final_club_df['team_name'] == 'Pittsburgh Steelers') & (final_club_df['date'] == '2020-12-20'),'club'] = 41
#final_club_df.loc[(final_club_df['team_name'] == 'Pittsburgh Steelers') & (final_club_df['date'] == '2020-12-27'),'club'] = 41

#final_club_df.to_csv('xyz.csv')

# %%
final_club_df = final_club_df.groupby(
    ['Week', 'Season','team_name']
).agg(
    {
        'club': ['sum'],
        'benchmark': ['sum'],
    }
)

final_club_benchmark = final_club_benchmark.groupby(
    ['Week', 'Season','team_name']
).agg(
    {
        'club': ['mean'],
        'benchmark': ['mean'],
    }
)

# %%
final_club_df.columns = ['AvgClub', 'AvgBenchmark']
final_club_df = final_club_df.reset_index()

final_club_benchmark.columns = ['AvgClub', 'AvgBenchmark']
final_club_benchmark = final_club_benchmark.reset_index()

# %%
#pd.set_option('display.max_rows', final_club_df.shape[0]+1)
final_club_df = final_club_df.replace(0, 1)
#final_club_df

# %%
#final_club_benchmark

# %%
# year = final_club_df.Season.unique()
# #print(year)
# GTI_list = []
# benchmark_list = []

# for i in year:
#     print(i)
#     club_df = final_club_df.loc[final_club_df['Season'] == i]
#     benchmark_df = final_club_benchmark.loc[final_club_benchmark['Season'] == i]
    
#     BenchOff = benchmark_df.loc[benchmark_df['Week'] == 'Off']['AvgClub'].values[0]
#     BenchReg = benchmark_df.loc[benchmark_df['Week'] == 'Reg']['AvgClub'].values[0]
#     BenchPost = benchmark_df.loc[benchmark_df['Week'] == 'Post']['AvgClub'].values[0]

#     conditions = [
#         (club_df['Week'] == 'Off'),
#         (club_df['Week'] == 'Reg'),
#         (club_df['Week'] == 'Post')
#     ]

#     # create a list of the values we want to assign for each condition
#     values = [club_df['AvgClub']/club_df['AvgBenchmark']*BenchOff/BenchReg,club_df['AvgClub']/club_df['AvgBenchmark'],club_df['AvgClub']/club_df['AvgBenchmark']*BenchPost/BenchReg]
#     # create a new column and use np.select to assign values to it using our lists as argumePost
#     club_df['Val'] = np.select(conditions, values)
#     GTI_list.append(club_df)
    
#     list = [['Arizona Cardinals',i, BenchOff/BenchReg, BenchPost/BenchReg, 1]] 
#     df = pd.DataFrame(list,columns=['team_name','Season','Off','Post','Reg']) 
#     benchmark_list.append(df)

# # display updated DataFrame
# #GTI_list
# Out:
# 2019

# %%
GTI_df = pd.concat(GTI_list,ignore_index=True)
bm_df = pd.concat(benchmark_list,ignore_index=True)

Final_WGTI_df = GTI_df.pivot_table('Val', ['team_name','Season'], 'Week')
Final_WGTI_df = Final_WGTI_df.reset_index()

# %%
#bm_df

# %%
#list = [['Arizona Cardinals', BenchOff/BenchReg, BenchPost/BenchReg, 1]] 
#df = pd.DataFrame(list,columns=['team_name','Off','Post','Reg']) 
#display(df)

# %%
# Final_WGTI_df = Final_WGTI_df.append(bm_df)

# Final_WGTI_df['WGTI'] = Final_WGTI_df['Off']*.1 + Final_WGTI_df['Post']*.3 + Final_WGTI_df['Reg']*.6
# Final_WGTI_df['rank'] = Final_WGTI_df.groupby('Season')['WGTI'].rank(method='first')
# #Final_WGTI_df['Season'] = Final_WGTI_df['Season'].astype(float)
# Final_WGTI_df = Final_WGTI_df.sort_values(['Season','rank'], ascending = [0,0])
# Final_WGTI_df
# Out:
# Week                 team_name Season       Off      Post       Reg      WGTI  \
# 7               Dallas Cowboys   2019  2.587811  6.716812  8.468354  7.354837
# 20        New England Patriots   2019  1.498461  9.136138  5.728571  6.327830
# 24         Philadelphia Eagles   2019  1.588122  3.691329  5.044872  4.293134
# 25         Pittsburgh Steelers   2019  1.331965  1.246177  5.707547  3.931578
# 21          New Orleans Saints   2019  0.688547  5.019040  3.833333  3.874567
# 14          Kansas City Chiefs   2019  0.602649  4.852294  3.922222  3.869287
# 4                Chicago Bears   2019  1.126294  2.467833  5.021583  3.865929
# 10           Green Bay Packers   2019  1.596255  1.260596  5.095477  3.595091
# 17            Los Angeles Rams   2019  0.552566  5.738825  3.009259  3.582460
# 6             Cleveland Browns   2019  1.429904  1.034580  4.287671  3.025967
# 27            Seattle Seahawks   2019  1.001751  1.315256  3.326923  2.490906
# ...

# %%
Final_WGTI_df.to_csv('GTI_club.csv',index=False)
